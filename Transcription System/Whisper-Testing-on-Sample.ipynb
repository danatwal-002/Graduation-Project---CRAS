# %%
import pandas as pd

# %%
import pandas as pd

r1 = pd.read_csv(r'D:\GP1\.venv\ipynb_Files\Code\CSV-Files\good-randomsample-tried.csv')
r1
# Out:
#                                            audio_path  \
# 0   D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 1   D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 2   D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 3   D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 4   D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# ..                                                ...
# 95  D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 96  D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 97  D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 98  D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
# 99  D:\GP1\.venv\ipynb_Files\Code\rand-sample-full...
#
#                                            transcript      transcription-time  \
# 0    المطبور                                      ...  0 days 00:04:33.619617
# 1    هو الحجاب                                    ...  0 days 00:01:41.319634
# 2    إنتما أشعر بالحزن                            ...  0 days 00:03:27.388265
# ...

# %%
good = pd.read_csv(r'D:\GP1\.venv\ipynb_Files\Code\CSV-Files\sample5-audios.csv')
good
# Out:
#                                            audio_path  \
# 0   /kaggle/input/random-sample-5/6e74cd84f37e5874...
# 1   /kaggle/input/random-sample-5/951520ec814c6a7f...
# 2   /kaggle/input/random-sample-5/ec45fa1549f24a69...
# 3   /kaggle/input/random-sample-5/acc3557664e67068...
# 4   /kaggle/input/random-sample-5/9db6445d0e82cde5...
# ..                                                ...
# 95  /kaggle/input/random-sample-5/2edc268f7195e38f...
# 96  /kaggle/input/random-sample-5/4d715ec48e3eceff...
# 97  /kaggle/input/random-sample-5/00e2907fbd0a47ee...
# 98  /kaggle/input/random-sample-5/f4d877a40a64d5a3...
# 99  /kaggle/input/random-sample-5/c3f0cb0da803f14a...
#
#                                            transcript transcription-time  \
# 0    تأغل هيتغر                                   ...            0:1.945
# 1    سلام عليكم                                   ...            0:1.940
# 2    فشلة إلى البحر                               ...            0:1.918
# ...

# %%
pd.set_option('max_colwidth',None)

# %%
good = pd.read_csv(r'D:\GP1\.venv\ipynb_Files\ASR_Data2\clear-audios-only\sample4-audios.csv')
good.head(40)
# Out:
#                                                             audio_path  \
# 0   /kaggle/input/random-sample-4/9769286738ace339592df97d10f19c57.mp3
# 1   /kaggle/input/random-sample-4/e9b98f09ebd5a53bd622e463b7a83f5d.mp3
# 2   /kaggle/input/random-sample-4/2d82a458b7c99e98a055bd2c638abc57.mp3
# 3   /kaggle/input/random-sample-4/2d91192825f753a79a6985dc0a0a55d0.mp3
# 4   /kaggle/input/random-sample-4/c5a89d53f87ea065342063e57e1d9f56.mp3
# 5   /kaggle/input/random-sample-4/1d031d057646a5a156deebc5fe95922a.mp3
# 6   /kaggle/input/random-sample-4/fad5e9337e6c7e9eeb0a7db89e646bdd.mp3
# 7   /kaggle/input/random-sample-4/12ddcd32ab6e7cd40e2b5a27227160b7.mp3
# 8   /kaggle/input/random-sample-4/33f3d52cee267f483655bed2931de0ca.mp3
# 9   /kaggle/input/random-sample-4/69ae60f2569d2a4a9d325b8f4f1614c8.mp3
# 10  /kaggle/input/random-sample-4/17332557b883128e5f8423991d7c3578.mp3
# 11  /kaggle/input/random-sample-4/6cc365aab203d67bbcc01e8d6fc29071.mp3
# ...

# %%
d1 = pd.read_csv(r'D:\GP1\.venv\ipynb_Files\ASR_Data2\clear-audios-only\sample2-audios.csv')
d1
# Out:
#                                            audio_path  \
# 0   /kaggle/input/random-sample-2/5b51f7773dcb7f1b...
# 1   /kaggle/input/random-sample-2/ca31426ca45b72d8...
# 2   /kaggle/input/random-sample-2/9a5183e6c561f92a...
# 3   /kaggle/input/random-sample-2/0fe6a16d0a7c1fd3...
# 4   /kaggle/input/random-sample-2/42a185238ca0fa9e...
# ..                                                ...
# 95  /kaggle/input/random-sample-2/cf47356391b8ceb8...
# 96  /kaggle/input/random-sample-2/25d8fbec541119d6...
# 97  /kaggle/input/random-sample-2/58ba6659ba98f70b...
# 98  /kaggle/input/random-sample-2/afd2755bb75c89d7...
# 99  /kaggle/input/random-sample-2/e514fc96e5a8b25b...
#
#                                            transcript transcription-time  \
# 0    الضخيرة تتميز المنطقة بشواطئها اللقية وساحلها...            0:7.095
# 1    مثباح ملعش                                   ...            0:1.929
# 2    فرجلاء الثلج ماء ماء في النهار وفي البحر شمس ...            0:5.987
# ...
